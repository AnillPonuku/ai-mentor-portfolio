# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the diverse competencies needed for successful AI development and deployment, from foundational to strategic:
#
# *   **Foundation (Domain & Data Science):** Understanding the specific business problem or domain, coupled with core data science and machine learning engineering skills to build and deploy models.
# *   **Interaction (Prompt Engineering):** Expertise in crafting effective prompts to interact with and extract value from advanced foundation models like large language models.
# *   **Integration (Orchestration):** The ability to integrate and orchestrate various AI components, APIs, and microservices into cohesive, functional systems and workflows.
# *   **Strategy (Product & Ethics):** High-level skills in AI product management, defining value propositions, user experience, strategic vision, and ensuring ethical and responsible AI deployment.
